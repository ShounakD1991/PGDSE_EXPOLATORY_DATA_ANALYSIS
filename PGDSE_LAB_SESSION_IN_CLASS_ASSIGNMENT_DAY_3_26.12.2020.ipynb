# %% [markdown]
# <table align="center" width=100%>
#     <tr>
#         <td width="15%">
#             <img src="in_class.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                     <b> Inclass - Lab <br>(Day 3)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### About the dataset (Adult Income Data)
#
# The dataset contains information about the individuals' age, gender, and several attributes affecting the income of a person. <br> Attribute information:
#
# **age:** Age of an individual
#
# **workclass:** Working class of the individual
#
# **fnlwgt:** Weights based on the demographic characteristics
#
# **education:** Highest education of the individual
#
# **education.num:** Education encoded with unique numbers
#
# **marital.status:** Marital status of the individual
#
# **occupation:** Occupation of the individual
#
# **relationship:** Relation of the individual in the family
#
# **race:** Race of the individual
#
# **sex:** Gender of the individual
#
# **capital.gain:** Gain amount of the individual
#
# **capital.loss:** Loss amount of the individual
#
# **hours.per.week:** Working hours per week
#
# **native.country:** The native country of the individual
#
# **income:** Income of the individual

# %% [markdown]
# ##  Table of Content
#
# 1. **[Quantitative and Quantitative Analysis](#quan)**
# 2. **[Categorical and Quantitative Analysis](#catquan)**
# 3. **[Categorical and Categorical Analysis](#cat)**

# %% [markdown]
# **Import the required libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Load the adult dataset and check the first five observations

# %%
df=pd.read_csv("/content/drive/MyDrive/PGDSE/EDA/LAB/IN_CLASS/DAY 3/adult.csv")
df.head()
# Out:
#    age workclass  fnlwgt  ... hours.per.week  native.country income
# 0   90         ?   77053  ...             40   United-States  <=50K
# 1   82   Private  132870  ...             18   United-States  <=50K
# 2   66         ?  186061  ...             40   United-States  <=50K
# 3   54   Private  140359  ...             40   United-States  <=50K
# 4   41   Private  264663  ...             40   United-States  <=50K
#
# [5 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education.num   32561 non-null  int64
#  5   marital.status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital.gain    32561 non-null  int64
#  11  capital.loss    32561 non-null  int64
#  12  hours.per.week  32561 non-null  int64
#  13  native.country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# <a id="quan"> </a>
# ## 1. Quantitative and Quantitative Analysis

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>1. Is there any effect of a person's age on the working hours</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(10,5),dpi=100)
sns.scatterplot(data=df,x='age',y='hours.per.week')
plt.xlabel('Age')
plt.ylabel("Hours/week")
plt.title("Scatter plot of working hours as per age")
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>2. Analyze the trend of the capital gain amount for different educational qualifications</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df1=pd.pivot_table(data=df,index='education',values='capital.gain',aggfunc='mean')
df1.reset_index(inplace=True)
df1
# Out:
#        education  capital.gain
# 0           10th    404.574491
# 1           11th    215.097872
# 2           12th    284.087760
# 3        1st-4th    125.875000
# 4        5th-6th    176.021021
# 5        7th-8th    233.939628
# 6            9th    342.089494
# 7     Assoc-acdm    640.399250
# 8      Assoc-voc    715.051375
# 9      Bachelors   1756.299533
# 10     Doctorate   4770.145278
# 11       HS-grad    576.800114
# 12       Masters   2562.563552
# 13     Preschool    898.392157
# 14   Prof-school  10414.416667
# 15  Some-college    598.824167

# %%
plt.figure(figsize=(10,5),dpi=100)
sns.barplot(data=df1,x=df1['education'],y=df1['capital.gain'])
plt.xlabel('Education Qualification')
plt.ylabel("Capital Gain")
plt.title("Barplot of Capital Gained with respect to different education")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>3. Check the effect of working hours of individuals on capital gain </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(10,5),dpi=100)
sns.scatterplot(data=df,y=df['capital.gain'],x='hours.per.week')
plt.ylabel('Capital Gain')
plt.xlabel("Hours/week")
plt.title("Scatter plot of capital gain as working hours")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>4.  Find the trend in the average working hours corresponding to the age of an individual</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df2=pd.pivot_table(data=df,index='age',values='hours.per.week')
df2.reset_index(inplace=True)
df2
# Out:
#     age  hours.per.week
# 0    17       21.367089
# 1    18       25.912727
# 2    19       30.678371
# 3    20       32.280212
# 4    21       34.034722
# ..  ...             ...
# 68   85       29.333333
# 69   86       40.000000
# 70   87        2.000000
# 71   88       40.000000
# 72   90       36.813953
#
# [73 rows x 2 columns]

# %%
plt.figure(figsize=(10,5),dpi=100)
sns.scatterplot(data=df2,x='age',y='hours.per.week')
plt.ylabel('Hours/week')
plt.xlabel('Age')
plt.title("Scatter plot of Working Hours for different age people")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>5. Check the distribution of the average capital loss corresponding to the age</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df3=pd.pivot_table(data=df,index='age',values='capital.loss',aggfunc='mean')
df3.reset_index(inplace=True)
df3
# Out:
#     age  capital.loss
# 0    17     41.751899
# 1    18     44.336364
# 2    19     43.915730
# 3    20     33.298805
# 4    21     51.636111
# ..  ...           ...
# 68   85      0.000000
# 69   86      0.000000
# 70   87      0.000000
# 71   88      0.000000
# 72   90    152.604651
#
# [73 rows x 2 columns]

# %%
plt.figure(figsize=(10,5),dpi=100)
sns.scatterplot(data=df3,x='age',y='capital.loss')
plt.ylabel('Capital Loss')
plt.xlabel('Age')
plt.title("Scatter plot of Capital Loss for different age people")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>6. Is there a negative relation between capital gain and age?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(10,5),dpi=100)
sns.scatterplot(data=df,x='age',y='capital.gain')
plt.ylabel('Capital Gain')
plt.xlabel('Age')
plt.title("Scatter plot of Capital Gain for different age people")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,5),dpi=100)
sns.heatmap(df[['capital.gain','age']].corr(),annot=True)
plt.title("Heat Map of Capital Gain for different age people")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <a id="catquan"> </a>
# ## 2. Categorical and Quantitative Analysis

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>7. Compare the average age with levels of income </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df4=pd.pivot_table(data=df,index='income',values='age',aggfunc='mean')
df4.reset_index(inplace=True)
df4
# Out:
#   income        age
# 0  <=50K  36.783738
# 1   >50K  44.249841

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>8. Check the distribution of working hours with respect to the gender of the individual</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(10,5),dpi=100)
sns.violinplot(data=df,x='sex',y='hours.per.week',split=True)
plt.xlabel("Gender")
plt.ylabel("Hours/Week")
plt.title("Violinplot of Hours/Week for different genders")
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>9. Compare the income of individuals based on their education</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df5=pd.crosstab(df['income'],df['education'])
df5
# Out:
# education  10th  11th  12th  ...  Preschool  Prof-school  Some-college
# income                       ...
# <=50K       871  1115   400  ...         51          153          5904
# >50K         62    60    33  ...          0          423          1387
#
# [2 rows x 16 columns]

# %%
df5.plot(kind='bar',sharex=False,figsize=(10,5))
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>10. Find the average age of males and females</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df6=pd.pivot_table(data=df,values='age',index='sex')
df6.reset_index()
df6
# Out:
#               age
# sex
# Female  36.858230
# Male    39.433547

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>11. Compare the distribution of working hours for the distinct classes of income
#  </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(10,8),dpi=100)
sns.violinplot(data=df,x='hours.per.week',y='income')
plt.title("Distribution of Hours/week for distinct class of income")
plt.xlabel("Hours/week")
plt.ylabel("Income")
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>12. Identify the positively skewed distributions of age based on the gender and race of the individual
#  </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(15,5),dpi=100)
sns.violinplot(data=df,x='age',y='race',hue='sex',split='sex')
plt.title("Distribution of age based on the gender and race")
plt.xlabel("Age")
plt.ylabel("Race")
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>13. Compare the working hours for each working class</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(15,8),dpi=100)
sns.violinplot(data=df,y=df['hours.per.week'],x=df['workclass'])
plt.xlabel("Work class")
plt.ylabel("Hours/Week")
plt.title("Violinplot of hours/week by different workclass")
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>14. Compare the weightage based on demographic characteristics by gender</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(15,5),dpi=100)
sns.violinplot(data=df,x=df['sex'],y=df['fnlwgt'])
plt.xlabel("Gender")
plt.ylabel("Weight")
plt.title("Violinplot of weight by different gender")
plt.show()

# %% [markdown]
# <a id="cat"> </a>
# ## 3. Categorical and Categorical Analysis

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>15. Study the variation in income by gender</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df7=pd.crosstab(df['sex'],df['income'])
df7.reset_index(inplace=True)
df7
# Out:
# income     sex  <=50K  >50K
# 0       Female   9592  1179
# 1         Male  15128  6662

# %%
df7
# Out:
# income     sex  <=50K  >50K
# 0       Female   9592  1179
# 1         Male  15128  6662

# %%
df7.plot(kind='bar')

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>16. Compare the income by race</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df8=pd.crosstab(df['income'],df['race'])
df8.reset_index(inplace=True)

# %%
df8.plot(kind='bar',sharex=False,figsize=(10,5))
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>17. Is there an all male profession according to the data?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
pd.crosstab(df['occupation'],df['sex']).apply(lambda r:r/(r.sum())*100,axis=1)
# Out:
# sex                   Female        Male
# occupation
# ?                  45.632122   54.367878
# Adm-clerical       67.294430   32.705570
# Armed-Forces        0.000000  100.000000
# Craft-repair        5.415955   94.584045
# Exec-managerial    28.504673   71.495327
# Farming-fishing     6.539235   93.460765
# Handlers-cleaners  11.970803   88.029197
# Machine-op-inspct  27.472527   72.527473
# Other-service      54.628225   45.371775
# Priv-house-serv    94.630872    5.369128
# Prof-specialty     36.594203   63.405797
# Protective-serv    11.710324   88.289676
# Sales              34.602740   65.397260
# Tech-support       37.500000   62.500000
# Transport-moving    5.635567   94.364433

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>18. How does income vary with working class?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
pd.crosstab(df['workclass'],df['income']).apply(lambda r:r/(r.sum())*100,axis=1)
# Out:
# income                 <=50K       >50K
# workclass
# ?                  89.596950  10.403050
# Federal-gov        61.354167  38.645833
# Local-gov          70.520784  29.479216
# Never-worked      100.000000   0.000000
# Private            78.132711  21.867289
# Self-emp-inc       44.265233  55.734767
# Self-emp-not-inc   71.507281  28.492719
# State-gov          72.804314  27.195686
# Without-pay       100.000000   0.000000

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>19. How is income related to marital status?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
pd.crosstab(df['marital.status'],df['income']).apply(lambda r:r/(r.sum())*100,axis=1)
# Out:
# income                     <=50K       >50K
# marital.status
# Divorced               89.579113  10.420887
# Married-AF-spouse      56.521739  43.478261
# Married-civ-spouse     55.315171  44.684829
# Married-spouse-absent  91.866029   8.133971
# Never-married          95.403913   4.596087
# Separated              93.560976   6.439024
# Widowed                91.440081   8.559919

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>20. Compare the income for different occupations</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
pd.crosstab(df['occupation'],df['income']).apply(lambda r:r/(r.sum())*100,axis=1)
# Out:
# income                 <=50K       >50K
# occupation
# ?                  89.636462  10.363538
# Adm-clerical       86.551724  13.448276
# Armed-Forces       88.888889  11.111111
# Craft-repair       77.335936  22.664064
# Exec-managerial    51.598623  48.401377
# Farming-fishing    88.430584  11.569416
# Handlers-cleaners  93.722628   6.277372
# Machine-op-inspct  87.512488  12.487512
# Other-service      95.842185   4.157815
# Priv-house-serv    99.328859   0.671141
# Prof-specialty     55.096618  44.903382
# Protective-serv    67.488444  32.511556
# Sales              73.068493  26.931507
# Tech-support       69.504310  30.495690
# Transport-moving   79.962430  20.037570
